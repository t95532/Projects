# %% [markdown]
# ### <font color="red"> CASE STUDY: Prediction of Laptop Prices based on Specifications

# %%
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt
import seaborn as sns
import requests
from bs4 import BeautifulSoup
import csv

# %%
#data to be scrapped
'Name'
'Price'
'Reviews'
'Processor'
'Ram'
'OS'
'Storage'
'Display'
# Out:
# 'Display'

# %% [markdown]
# ### <font color="red"> The data is Extracted from Flipkart using BeautifulSoup

# %%
Name =[]
Price =[]
Processor =[]
Ram = []
OperatingSystem =[]
storage =[]
Display =[]
warrenty =[]

for i in range(1, 50):
    base_url='https://www.flipkart.com/search?q=laptops&otracker=search&otracker1=search&marketplace=FLIPKART&as-show=off&as=off&page='
    url = (base_url+str(i))
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        for data in soup.findAll('div',class_='_3pLy-c row'):
            names=data.find('div', attrs={'class':'_4rR01T'})
            price=data.find('div', attrs={'class':'_30jeq3 _1_WHN1'})
            specification = data.find('div', attrs={'class':'fMghEO'})

            for each in specification:
                col=each.find_all('li', attrs={'class':'rgWa7D'})
                Pro =col[0].text
                ram = col[1].text
                Os = col[2].text
                stor = col[3].text
                Dis = col[4].text
                try:
                  warrent = col[5].text
                except IndexError:
                  warrent = np.nan


            Name.append(names.text)
            Price.append(price.text)
            Processor.append(Pro)
            Ram.append(ram)
            OperatingSystem.append(Os)
            storage.append(stor)
            Display.append(Dis)
            warrenty.append(warrent)

# %%
print('name:',len(Name))
print('Price:',len(Price))
print('Processor:',len(Processor))
print('Ram:',len(Ram))
print('OperatingSystem:',len(OperatingSystem))
print('storage:',len(storage))
print('Display:',len(Display))
print('warrenty:',len(warrenty))
# Out:
# name: 984
# Price: 984
# Processor: 984
# Ram: 984
# OperatingSystem: 984
# storage: 984
# Display: 984
# warrenty: 984

# %% [markdown]
# ### <font color="Blue">Problem-Statement:
# ### <font color ='green'> Prediction of Laptop Prices based on their Features

# %%
#Creating the dataframe
df = pd.DataFrame({'Name':Name,'Price':Price,'Processor':Processor,'Ram':Ram,'OS':OperatingSystem,
                     'storage':storage,'Display':Display,"warrenty":warrenty})

# %%
#extracted the data into dataframe
df
# Out:
#                                                   Name    Price  \
# 0    Primebook S Wifi MT8183 - (4 GB/128 GB EMMC St...  ₹10,990
# 1    Infinix X2 Slim Intel Core i5 11th Gen 1155G7 ...  ₹34,990
# 2    Infinix X2 Slim Intel Core i3 11th Gen 1115G4 ...  ₹26,990
# 3    ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹29,990
# 4    APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹94,990
# ..                                                 ...      ...
# 979  MSI Core i7 12th Gen 1255U - (8 GB/512 GB SSD/...  ₹60,990
# 980  Wings Nuvobook S2 Aluminium Alloy Metal Body I...  ₹27,990
# 981  Wings Nuvobook S2 Aluminium Alloy Metal Body I...  ₹27,990
# 982  HP Core i5 7th Gen 7200U - (8 GB/256 GB SSD/Wi...  ₹54,000
# 983  ASUS Core i5 12th Gen - (16 GB/512 GB SSD/Wind...  ₹70,990
#
#                                              Processor  \
# 0                            MediaTek MT8183 Processor
# 1                   Intel Core i5 Processor (11th Gen)
# 2                   Intel Core i3 Processor (11th Gen)
# 3                   Intel Core i3 Processor (11th Gen)
# 4                                   Apple M2 Processor
# ..                                                 ...
# 979                 Intel Core i7 Processor (12th Gen)
# 980                 Intel Core i3 Processor (11th Gen)
# 981                 Intel Core i3 Processor (11th Gen)
# 982  Pre-installed Genuine Windows 10 Operating Sys...
# 983                 Intel Core i5 Processor (12th Gen)
#
#                                    Ram                                  OS  \
# 0                      4 GB LPDDR4 RAM            Android Operating System
# 1                    16 GB LPDDR4X RAM  64 bit Windows 11 Operating System
# 2                     8 GB LPDDR4X RAM  64 bit Windows 11 Operating System
# 3                        8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 4              8 GB Unified Memory RAM             Mac OS Operating System
# ..                                 ...                                 ...
# 979                      8 GB DDR4 RAM         Windows 11 Operating System
# 980                      8 GB DDR4 RAM         Windows 11 Operating System
# 981                      8 GB DDR4 RAM         Windows 11 Operating System
# 982  Intel Core i5 Processor (7th Gen)                       8 GB DDR3 RAM
# 983                     16 GB DDR4 RAM         Windows 11 Operating System
#
#                                 storage                        Display  \
# 0          29.46 cm (11.6 Inch) Display  1 Year Pick and Drop Warranty
# 1                            512 GB SSD     35.56 cm (14 inch) Display
# 2                            512 GB SSD     35.56 cm (14 inch) Display
# 3                            256 GB SSD   39.62 cm (15.6 Inch) Display
# 4                            256 GB SSD   34.54 cm (13.6 Inch) Display
# ..                                  ...                            ...
# 979                          512 GB SSD     35.56 cm (14 Inch) Display
# 980                          512 GB SSD   39.62 cm (15.6 Inch) Display
# 981                          512 GB SSD   39.62 cm (15.6 Inch) Display
# 982  64 bit Windows 10 Operating System                     256 GB SSD
# 983                          512 GB SSD   39.62 cm (15.6 inch) Display
#
#                                               warrenty
# 0                                                  NaN
# 1                                                   NA
# 2                                                   NA
# 3                                       Not Applicable
# 4    Built-in Apps: iMovie, Siri, GarageBand, Pages...
# ..                                                 ...
# 979                           1 Year Carry-in warranty
# 980                             1 Year Onsite Warranty
# 981                             1 Year Onsite Warranty
# 982                       33.78 cm (13.3 inch) Display
# 983                                    1 Year Warranty
#
# [984 rows x 8 columns]

# %%
#exporting the dataframe into csv format
df.to_csv('data.csv', index=False)

# %%
#reading the dataframe
data = pd.read_csv('data.csv')

# %%
data.head()
# Out:
#                                                 Name    Price  \
# 0  Primebook S Wifi MT8183 - (4 GB/128 GB EMMC St...  ₹10,990
# 1  Infinix X2 Slim Intel Core i5 11th Gen 1155G7 ...  ₹34,990
# 2  Infinix X2 Slim Intel Core i3 11th Gen 1115G4 ...  ₹26,990
# 3  ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹29,990
# 4  APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹94,990
#
#                             Processor                      Ram  \
# 0           MediaTek MT8183 Processor          4 GB LPDDR4 RAM
# 1  Intel Core i5 Processor (11th Gen)        16 GB LPDDR4X RAM
# 2  Intel Core i3 Processor (11th Gen)         8 GB LPDDR4X RAM
# 3  Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 4                  Apple M2 Processor  8 GB Unified Memory RAM
#
#                                    OS                       storage  \
# 0            Android Operating System  29.46 cm (11.6 Inch) Display
# 1  64 bit Windows 11 Operating System                    512 GB SSD
# 2  64 bit Windows 11 Operating System                    512 GB SSD
# 3  64 bit Windows 11 Operating System                    256 GB SSD
# 4             Mac OS Operating System                    256 GB SSD
#
#                          Display  \
# 0  1 Year Pick and Drop Warranty
# 1     35.56 cm (14 inch) Display
# 2     35.56 cm (14 inch) Display
# 3   39.62 cm (15.6 Inch) Display
# 4   34.54 cm (13.6 Inch) Display
#
#                                             warrenty
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                     Not Applicable
# 4  Built-in Apps: iMovie, Siri, GarageBand, Pages...

# %%
data.tail()
# Out:
#                                                   Name    Price  \
# 979  MSI Core i7 12th Gen 1255U - (8 GB/512 GB SSD/...  ₹60,990
# 980  Wings Nuvobook S2 Aluminium Alloy Metal Body I...  ₹27,990
# 981  Wings Nuvobook S2 Aluminium Alloy Metal Body I...  ₹27,990
# 982  HP Core i5 7th Gen 7200U - (8 GB/256 GB SSD/Wi...  ₹54,000
# 983  ASUS Core i5 12th Gen - (16 GB/512 GB SSD/Wind...  ₹70,990
#
#                                              Processor  \
# 979                 Intel Core i7 Processor (12th Gen)
# 980                 Intel Core i3 Processor (11th Gen)
# 981                 Intel Core i3 Processor (11th Gen)
# 982  Pre-installed Genuine Windows 10 Operating Sys...
# 983                 Intel Core i5 Processor (12th Gen)
#
#                                    Ram                           OS  \
# 979                      8 GB DDR4 RAM  Windows 11 Operating System
# 980                      8 GB DDR4 RAM  Windows 11 Operating System
# 981                      8 GB DDR4 RAM  Windows 11 Operating System
# 982  Intel Core i5 Processor (7th Gen)                8 GB DDR3 RAM
# 983                     16 GB DDR4 RAM  Windows 11 Operating System
#
#                                 storage                       Display  \
# 979                          512 GB SSD    35.56 cm (14 Inch) Display
# 980                          512 GB SSD  39.62 cm (15.6 Inch) Display
# 981                          512 GB SSD  39.62 cm (15.6 Inch) Display
# 982  64 bit Windows 10 Operating System                    256 GB SSD
# 983                          512 GB SSD  39.62 cm (15.6 inch) Display
#
#                          warrenty
# 979      1 Year Carry-in warranty
# 980        1 Year Onsite Warranty
# 981        1 Year Onsite Warranty
# 982  33.78 cm (13.3 inch) Display
# 983               1 Year Warranty

# %%
#checking for duplicate values
data.duplicated().sum()
# Out:
# 455

# %%
data[data.duplicated()]
# Out:
#                                                   Name    Price  \
# 14   Infinix X2 Slim Intel Core i3 11th Gen 1115G4 ...  ₹26,990
# 17   Infinix X2 Slim Intel Core i3 11th Gen 1115G4 ...  ₹26,990
# 26   Primebook S Wifi MT8183 - (4 GB/128 GB EMMC St...  ₹10,990
# 27   CHUWI Core i3 10th Gen 1005G1 - (8 GB/512 GB S...  ₹20,990
# 30   Infinix X2 Slim Intel Core i5 11th Gen 1155G7 ...  ₹34,990
# ..                                                 ...      ...
# 971  Wings Nuvobook Pro Aluminium Alloy Metal Body ...  ₹45,990
# 976  Wings Nuvobook V1 Aluminium Alloy Metal Body I...  ₹34,990
# 977  Wings Nuvobook V1 Aluminium Alloy Metal Body I...  ₹34,990
# 980  Wings Nuvobook S2 Aluminium Alloy Metal Body I...  ₹27,990
# 981  Wings Nuvobook S2 Aluminium Alloy Metal Body I...  ₹27,990
#
#                                              Processor  \
# 14                  Intel Core i3 Processor (11th Gen)
# 17                  Intel Core i3 Processor (11th Gen)
# 26                           MediaTek MT8183 Processor
# 27   Stylish, Thin and Portable Light Weight Laptop...
# 30                  Intel Core i5 Processor (11th Gen)
# ..                                                 ...
# 971                 Intel Core i7 Processor (11th Gen)
# 976                 Intel Core i5 Processor (11th Gen)
# 977                 Intel Core i5 Processor (11th Gen)
# 980                 Intel Core i3 Processor (11th Gen)
# 981                 Intel Core i3 Processor (11th Gen)
#
#                                     Ram                                  OS  \
# 14                     8 GB LPDDR4X RAM  64 bit Windows 11 Operating System
# 17                     8 GB LPDDR4X RAM  64 bit Windows 11 Operating System
# 26                      4 GB LPDDR4 RAM            Android Operating System
# 27   Intel Core i3 Processor (10th Gen)                       8 GB DDR4 RAM
# 30                    16 GB LPDDR4X RAM  64 bit Windows 11 Operating System
# ..                                  ...                                 ...
# 971                      16 GB DDR4 RAM         Windows 11 Operating System
# 976                       8 GB DDR4 RAM         Windows 11 Operating System
# 977                       8 GB DDR4 RAM         Windows 11 Operating System
# 980                       8 GB DDR4 RAM         Windows 11 Operating System
# 981                       8 GB DDR4 RAM         Windows 11 Operating System
#
#                                 storage                        Display  \
# 14                           512 GB SSD     35.56 cm (14 inch) Display
# 17                           512 GB SSD     35.56 cm (14 inch) Display
# 26         29.46 cm (11.6 Inch) Display  1 Year Pick and Drop Warranty
# 27   64 bit Windows 11 Operating System                     512 GB SSD
# 30                           512 GB SSD     35.56 cm (14 inch) Display
# ..                                  ...                            ...
# 971                          512 GB SSD     35.56 cm (14 Inch) Display
# 976                          512 GB SSD   39.62 cm (15.6 Inch) Display
# 977                          512 GB SSD   39.62 cm (15.6 Inch) Display
# 980                          512 GB SSD   39.62 cm (15.6 Inch) Display
# 981                          512 GB SSD   39.62 cm (15.6 Inch) Display
#
#                        warrenty
# 14                          NaN
# 17                          NaN
# 26                          NaN
# 27   35.56 cm (14 inch) Display
# 30                          NaN
# ..                          ...
# 971      1 Year Onsite Warranty
# 976      1 Year Onsite Warranty
# 977      1 Year Onsite Warranty
# 980      1 Year Onsite Warranty
# 981      1 Year Onsite Warranty
#
# [455 rows x 8 columns]

# %%
#Dropping the Duplicate records
data= data.drop_duplicates().reset_index(drop=True)
data
# Out:
#                                                   Name    Price  \
# 0    Primebook S Wifi MT8183 - (4 GB/128 GB EMMC St...  ₹10,990
# 1    Infinix X2 Slim Intel Core i5 11th Gen 1155G7 ...  ₹34,990
# 2    Infinix X2 Slim Intel Core i3 11th Gen 1115G4 ...  ₹26,990
# 3    ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹29,990
# 4    APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹94,990
# ..                                                 ...      ...
# 524  ASUS Vivobook Pro 15 OLED Core i5 12th Gen 124...  ₹89,990
# 525  DELL Inspiron Core i3 11th Gen 115G4 - (8 GB/2...  ₹35,990
# 526  MSI Core i7 12th Gen 1255U - (8 GB/512 GB SSD/...  ₹60,990
# 527  HP Core i5 7th Gen 7200U - (8 GB/256 GB SSD/Wi...  ₹54,000
# 528  ASUS Core i5 12th Gen - (16 GB/512 GB SSD/Wind...  ₹70,990
#
#                                              Processor  \
# 0                            MediaTek MT8183 Processor
# 1                   Intel Core i5 Processor (11th Gen)
# 2                   Intel Core i3 Processor (11th Gen)
# 3                   Intel Core i3 Processor (11th Gen)
# 4                                   Apple M2 Processor
# ..                                                 ...
# 524                 Intel Core i5 Processor (12th Gen)
# 525                 Intel Core i3 Processor (11th Gen)
# 526                 Intel Core i7 Processor (12th Gen)
# 527  Pre-installed Genuine Windows 10 Operating Sys...
# 528                 Intel Core i5 Processor (12th Gen)
#
#                                    Ram                                  OS  \
# 0                      4 GB LPDDR4 RAM            Android Operating System
# 1                    16 GB LPDDR4X RAM  64 bit Windows 11 Operating System
# 2                     8 GB LPDDR4X RAM  64 bit Windows 11 Operating System
# 3                        8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 4              8 GB Unified Memory RAM             Mac OS Operating System
# ..                                 ...                                 ...
# 524                   16 GB LPDDR5 RAM  64 bit Windows 11 Operating System
# 525                      8 GB DDR4 RAM  64 bit Windows 10 Operating System
# 526                      8 GB DDR4 RAM         Windows 11 Operating System
# 527  Intel Core i5 Processor (7th Gen)                       8 GB DDR3 RAM
# 528                     16 GB DDR4 RAM         Windows 11 Operating System
#
#                                 storage                        Display  \
# 0          29.46 cm (11.6 Inch) Display  1 Year Pick and Drop Warranty
# 1                            512 GB SSD     35.56 cm (14 inch) Display
# 2                            512 GB SSD     35.56 cm (14 inch) Display
# 3                            256 GB SSD   39.62 cm (15.6 Inch) Display
# 4                            256 GB SSD   34.54 cm (13.6 Inch) Display
# ..                                  ...                            ...
# 524                          512 GB SSD   39.62 cm (15.6 Inch) Display
# 525                          256 GB SSD   39.62 cm (15.6 inch) Display
# 526                          512 GB SSD     35.56 cm (14 Inch) Display
# 527  64 bit Windows 10 Operating System                     256 GB SSD
# 528                          512 GB SSD   39.62 cm (15.6 inch) Display
#
#                                               warrenty
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                       Not Applicable
# 4    Built-in Apps: iMovie, Siri, GarageBand, Pages...
# ..                                                 ...
# 524                             1 Year Onsite Warranty
# 525              Office Home and Student 2019 included
# 526                           1 Year Carry-in warranty
# 527                       33.78 cm (13.3 inch) Display
# 528                                    1 Year Warranty
#
# [529 rows x 8 columns]

# %%
#checking for null values
data.isnull().sum()
# Out:
# Name          0
# Price         0
# Processor     0
# Ram           0
# OS            0
# storage       0
# Display       0
# warrenty     19
# dtype: int64

# %%
#dropping null values
data= data.dropna().reset_index(drop=True)
data
# Out:
#                                                   Name    Price  \
# 0    ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  ₹29,990
# 1    APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  ₹94,990
# 2    DELL Inspiron Core i3 11th Gen 1115G4 - (8 GB/...  ₹36,590
# 3    HP 2023 Ryzen 3 Dual Core 3250U - (8 GB/512 GB...  ₹34,990
# 4    CHUWI Core i3 10th Gen 1005G1 - (8 GB/512 GB S...  ₹20,990
# ..                                                 ...      ...
# 505  ASUS Vivobook Pro 15 OLED Core i5 12th Gen 124...  ₹89,990
# 506  DELL Inspiron Core i3 11th Gen 115G4 - (8 GB/2...  ₹35,990
# 507  MSI Core i7 12th Gen 1255U - (8 GB/512 GB SSD/...  ₹60,990
# 508  HP Core i5 7th Gen 7200U - (8 GB/256 GB SSD/Wi...  ₹54,000
# 509  ASUS Core i5 12th Gen - (16 GB/512 GB SSD/Wind...  ₹70,990
#
#                                              Processor  \
# 0                   Intel Core i3 Processor (11th Gen)
# 1                                   Apple M2 Processor
# 2                   Intel Core i3 Processor (11th Gen)
# 3                      AMD Ryzen 3 Dual Core Processor
# 4    Stylish, Thin and Portable Light Weight Laptop...
# ..                                                 ...
# 505                 Intel Core i5 Processor (12th Gen)
# 506                 Intel Core i3 Processor (11th Gen)
# 507                 Intel Core i7 Processor (12th Gen)
# 508  Pre-installed Genuine Windows 10 Operating Sys...
# 509                 Intel Core i5 Processor (12th Gen)
#
#                                     Ram                                  OS  \
# 0                         8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 1               8 GB Unified Memory RAM             Mac OS Operating System
# 2                         8 GB DDR4 RAM  64 bit Windows 11 Operating System
# 3                         8 GB DDR4 RAM         Windows 11 Operating System
# 4    Intel Core i3 Processor (10th Gen)                       8 GB DDR4 RAM
# ..                                  ...                                 ...
# 505                    16 GB LPDDR5 RAM  64 bit Windows 11 Operating System
# 506                       8 GB DDR4 RAM  64 bit Windows 10 Operating System
# 507                       8 GB DDR4 RAM         Windows 11 Operating System
# 508   Intel Core i5 Processor (7th Gen)                       8 GB DDR3 RAM
# 509                      16 GB DDR4 RAM         Windows 11 Operating System
#
#                                 storage                       Display  \
# 0                            256 GB SSD  39.62 cm (15.6 Inch) Display
# 1                            256 GB SSD  34.54 cm (13.6 Inch) Display
# 2                            512 GB SSD  39.62 cm (15.6 inch) Display
# 3                            512 GB SSD  39.62 cm (15.6 Inch) Display
# 4    64 bit Windows 11 Operating System                    512 GB SSD
# ..                                  ...                           ...
# 505                          512 GB SSD  39.62 cm (15.6 Inch) Display
# 506                          256 GB SSD  39.62 cm (15.6 inch) Display
# 507                          512 GB SSD    35.56 cm (14 Inch) Display
# 508  64 bit Windows 10 Operating System                    256 GB SSD
# 509                          512 GB SSD  39.62 cm (15.6 inch) Display
#
#                                               warrenty
# 0                                       Not Applicable
# 1    Built-in Apps: iMovie, Siri, GarageBand, Pages...
# 2                               1 Year Onsite Warranty
# 3                               1 Year Onsite Warranty
# 4                           35.56 cm (14 inch) Display
# ..                                                 ...
# 505                             1 Year Onsite Warranty
# 506              Office Home and Student 2019 included
# 507                           1 Year Carry-in warranty
# 508                       33.78 cm (13.3 inch) Display
# 509                                    1 Year Warranty
#
# [510 rows x 8 columns]

# %%
data.dtypes
# Out:
# Name         object
# Price        object
# Processor    object
# Ram          object
# OS           object
# storage      object
# Display      object
# warrenty     object
# dtype: object

# %%
#getting the unique types of laptops based on the features like
list1 = ['Processor','Ram','OS','storage','Display']

# %%
def unique(df, col):
  print(col, len(df[col].unique()))

# %%
for i in list1:
  unique(data, i)
# Out:
# Processor 66
# Ram 36
# OS 23
# storage 22
# Display 59

# %%
def value_counts(df, col):
  print(df[col].value_counts())

# %%
for i in list1:
  value_counts(data, i)
  print('>>>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<<')
# Out:
# Intel Core i5 Processor (12th Gen)                                            69
# Intel Core i3 Processor (11th Gen)                                            45
# AMD Ryzen 5 Hexa Core Processor                                               44
# Intel Core i5 Processor (11th Gen)                                            42
# AMD Ryzen 7 Octa Core Processor                                               39
#                                                                               ..
# Intel Celeron Quad Core Processor                                              1
# Get unparalleled power and reliability with the new Intel 12th Gen CPU         1
# Processor: Intel i7-1255U (Base- 3.50 GHz & Turbo up to 4.70 GHz) 10 Cores     1
# Intel Core i5 Processor (7th Gen)                                              1
# NVIDIA GeForce 940MX for High Graphics Performance                             1
# Name: Processor, Length: 66, dtype: int64
# >>>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<<
# 8 GB DDR4 RAM                                                                                                                                                                                                                                                                   205
# 16 GB DDR4 RAM                                                                                                                                                                                                                                                                  118
# 16 GB DDR5 RAM                                                                                                                                                                                                                                                                   39
# 16 GB LPDDR5 RAM                                                                                                                                                                                                                                                                 25
# 8 GB LPDDR5 RAM                                                                                                                                                                                                                                                                  17
# 32 GB DDR5 RAM                                                                                                                                                                                                                                                                   16
# 16 GB LPDDR4X RAM                                                                                                                                                                                                                                                                14
# 4 GB DDR4 RAM                                                                                                                                                                                                                                                                    12
# 8 GB LPDDR4X RAM                                                                                                                                                                                                                                                                 11
# 8 GB Unified Memory RAM                                                                                                                                                                                                                                                          10
# 8 GB DDR5 RAM                                                                                                                                                                                                                                                                     5
# 32 GB Unified Memory RAM                                                                                                                                                                                                                                                          3
# Intel Core i5 Processor (7th Gen)                                                                                                                                                                                                                                                 3
# RAM & Storage: 8GB DDR4 & 512GB SSD                                                                                                                                                                                                                                               3
# LPDDR5 RAM -faster & low power consuming                                                                                                                                                                                                                                          2
# RAM & Storage: 16GB DDR4 & 512GB SSD                                                                                                                                                                                                                                              2
# 16 GB LPDDR3 RAM                                                                                                                                                                                                                                                                  2
# 16 GB DDR4X RAM                                                                                                                                                                                                                                                                   2
# 32 GB LPDDR5 RAM                                                                                                                                                                                                                                                                  2
# 64 GB DDR5 RAM                                                                                                                                                                                                                                                                    2
# 16 GB LPDDR5X RAM                                                                                                                                                                                                                                                                 2
# 15.6 Inch Full HD OLED 16:9 aspect ratio, 0.2ms response time, 600nits HDR peak brightness, 100% DCI-P3 color gamut, VESA CERTIFIED Display HDR True Black 600, 1.07 billion colors, PANTONE Validated, Glossy display, 70% less harmful blue light, TUV Rheinland-certified      1
# AMD Ryzen 5 Hexa Core Processor                                                                                                                                                                                                                                                   1
# 8 GB DDR3 RAM                                                                                                                                                                                                                                                                     1
# Intel Core i3 Processor (10th Gen)                                                                                                                                                                                                                                                1
# 16 GB DDR RAM                                                                                                                                                                                                                                                                     1
# Intel Core i7 Processor (11th Gen)                                                                                                                                                                                                                                                1
# 8 GB DDR RAM                                                                                                                                                                                                                                                                      1
# 16 GB Unified Memory RAM                                                                                                                                                                                                                                                          1
# RAM & Storage: 8GB DDR4 & 1TB HDD + 256GB SSD                                                                                                                                                                                                                                     1
# RAM & Storage: 16GB, 2x8GB, DDR5, 4800Mhz & 512GB SSD                                                                                                                                                                                                                             1
# 15.6 inch Full HD AG Display (250 nits Brightness, 120Hz, Narrow Border)                                                                                                                                                                                                          1
# 15.6 inches Full HD, 2-sided narrow bezel, 120Hz, 250 Nits                                                                                                                                                                                                                        1
# Dual Fan Cooling with Metal AeroBlade 3D                                                                                                                                                                                                                                          1
# 32 GB LPDDR4X RAM                                                                                                                                                                                                                                                                 1
# RAM & Storage: 8GB DDR4 & 256GB SSD                                                                                                                                                                                                                                               1
# Name: Ram, dtype: int64
# >>>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<<
# Windows 11 Operating System                                                                                248
# 64 bit Windows 11 Operating System                                                                         166
# 64 bit Windows 10 Operating System                                                                          43
# Mac OS Operating System                                                                                     17
# DOS Operating System                                                                                         7
# 8 GB DDR4 RAM                                                                                                4
# Graphics & Keyboard: Integrated & Standard Keyboard                                                          4
# Windows 10 Operating System                                                                                  3
# Firmware TPM (Trusted Platform Module)-Improved Security of your PC                                          2
# 64 bit DOS Operating System                                                                                  2
# Windows 11 Home Operating System                                                                             2
# Alienware Command Center                                                                                     1
# 64 bit Linux/Ubuntu Operating System                                                                         1
# Linux/Ubuntu Operating System                                                                                1
# 128 GB SSD for Reduced Boot Up Time and in Game Loading                                                      1
# Improved thermal design with copper pipes & vents                                                            1
# Graphics & Keyboard: NVIDIAGeForceMX550 (2GB GDDR6) + Fingerprint Reader                                     1
# Display & Graphics: 15.6" FHD WVA AG 120Hz 250 nits Narrow Border & NVIDIA GEFORCE RTX 3050 (4GB GDDR6)      1
# Graphics & Keyboard: Integrated & Backlit Keyboard + Fingerprint Reader                                      1
# 16 GB DDR4 RAM                                                                                               1
# Graphics & Keyboard: Integrated & Backlit Keyboard+Fingerprint Reader                                        1
# Stylish & Portable Just 1.99 cm thin and 1.7 kg in weight. US MIL-STD 810H Military-grade durability         1
# 8 GB DDR3 RAM                                                                                                1
# Name: OS, dtype: int64
# >>>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<<
# 512 GB SSD                                                                        343
# 1 TB SSD                                                                           69
# 256 GB SSD                                                                         45
# 1 TB HDD|256 GB SSD                                                                12
# 2 TB SSD                                                                            9
# 1 TB HDD                                                                            8
# 64 bit Windows 10 Operating System                                                  4
# Display: 15.6" FHD WVA AG 120Hz 250 nits Narrow Border                              3
# FHD 1080p screen with 250 Nits brightness                                           2
# 128 GB SSD                                                                          2
# Display: 14.0" FHD+ WVA Truelife Touch Narrow Border 250 nits, Dell Active Pen      2
# Display: 15.6" FHD WVA AG Narrow Border                                             1
# 64 bit Windows 11 Operating System                                                  1
# Light Laptop without Optical Disk Drive                                             1
# Software & Keyboard: Win 11 + Office H&S 2021 & Backlit Keyboard Orange             1
# Intel Core i5 Processor (11th Gen)                                                  1
# Game shift key for Turbo boost of power                                             1
# Upgradable SSD Upto 512 GB and RAM Upto 32 GB                                       1
# 1 TB HDD|1 TB SSD                                                                   1
# Display: 14.0" FHD WVA AG Narrow Border 250 nits                                    1
# 1 TB HDD|128 GB SSD                                                                 1
# DOS Operating System                                                                1
# Name: storage, dtype: int64
# >>>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<<
# 39.62 cm (15.6 Inch) Display                                                                                                                  165
# 39.62 cm (15.6 inch) Display                                                                                                                  110
# 35.56 cm (14 Inch) Display                                                                                                                     49
# 35.56 cm (14 inch) Display                                                                                                                     34
# 40.64 cm (16 Inch) Display                                                                                                                     21
# 43.94 cm (17.3 Inch) Display                                                                                                                   13
# 33.78 cm (13.3 Inch) Display                                                                                                                    8
# 35.56 cm (14 Inch) Touchscreen Display                                                                                                          8
# 40.64 cm (16 inch) Display                                                                                                                      8
# 35.56 cm (14 inch) Touchscreen Display                                                                                                          6
# 33.78 cm (13.3 inch) Display                                                                                                                    5
# 34.54 cm (13.6 Inch) Display                                                                                                                    5
# 40.89 cm (16.1 Inch) Display                                                                                                                    4
# 100.63 cm (39.62 cm) Display                                                                                                                    4
# 96.52 cm (38 cm) Display                                                                                                                        4
# 39.62 cm (15.6 Inch) Touchscreen Display                                                                                                        4
# 34.04 cm (13.4 Inch) Touchscreen Display                                                                                                        3
# Intel Core i5 Processor (12th Gen)                                                                                                              3
# 38.86 cm (15.3 Inch) Display                                                                                                                    3
# 38.1 cm (15 inch) Display                                                                                                                       3
# 39.01 cm (15.36 inch) Display                                                                                                                   3
# 43.94 cm (17.3 inch) Display                                                                                                                    3
# 35.81 cm (14.1 inch) Display                                                                                                                    3
# 33.78 cm (13.3 Inch) Touchscreen Display                                                                                                        3
# 33.78 cm (13.3 inch) Touchscreen Display                                                                                                        2
# 40.64 cm (16 Inch) Touchscreen Display                                                                                                          2
# Latest WiFi 6                                                                                                                                   2
# 99.06 cm (39 cm) Display                                                                                                                        1
# 42.16 cm (16.6 inch) Display                                                                                                                    1
# 35.81 cm (14.1 Inch) Display                                                                                                                    1
# NVIDIA Geforce GTX 1050Ti for Desktop Level Performance                                                                                         1
# Ports: (1) HDMI 2.1, (3) SuperSpeed USB 3.2 Gen 1 Type-A, (1) USB Type C Gen 3.2 Display Port Alt-Mode, Headphone/Mic, (1) RJ45                 1
# 38.0 cm (14.96 inch) Display                                                                                                                    1
# 8 GB DDR4 RAM                                                                                                                                   1
# In-built Alienware Command center software with enhanced control over system settings                                                           1
# 35.56 cm (14 inches) Display                                                                                                                    1
# Ports: 2 USB 3.2 Gen 1 ports, 1 USB 2.0 port, 1 Headset jack, 1 HDMI 1.4 port*,1 Flip-Down RJ-45 port 10/100/1000 Mbps, 1 SD 3.0 card slot      1
# 34.04 cm (13.4 inch) Touchscreen Display                                                                                                        1
# 1 TB HDD                                                                                                                                        1
# 34.29 cm (13.5 Inch) Touchscreen Display                                                                                                        1
# 85.8 cm (33.78 cm) Touchscreen Display                                                                                                          1
# 45.72 cm (18 Inch) Display                                                                                                                      1
# 38.0 cm (14.96 cm) Display                                                                                                                      1
# 512 GB SSD                                                                                                                                      1
# Intel Core i3 Processor (12th Gen)                                                                                                              1
# 29.46 cm (11.6 inch) Display                                                                                                                    1
# Intel Core i3 Processor (11th Gen)                                                                                                              1
# 90.32 cm (35.56 cm) Display                                                                                                                     1
# 1 TB HDD|128 GB SSD                                                                                                                             1
# 1 TB HDD|256 GB SSD                                                                                                                             1
# Backlit chiclet keyboard, Finger Print Sensor for Faster System Access                                                                          1
# 38.0 cm (14.96 Inch) Display                                                                                                                    1
# Intel Core i7 Processor (12th Gen)                                                                                                              1
# 43.18 cm (17 Inch) Display                                                                                                                      1
# 36.07 cm (14.2 Inch) Touchscreen Display                                                                                                        1
# 1 TB SSD                                                                                                                                        1
# 35.0 cm (13.78 inch) Display                                                                                                                    1
# 41.15 cm (16.2 inch) Display                                                                                                                    1
# 256 GB SSD                                                                                                                                      1
# Name: Display, dtype: int64
# >>>>>>>>>>>>>>>>>>><<<<<<<<<<<<<<<<<<<<<<<

# %%
# we can see incorrect data in the dataframe adjust the dataframe by manupulating the data

# %%
#filtering the data wiith respect to Display column
keyword = 'Display'

filtered_data = data[data['Display'].str.contains(keyword, case=False)]

filtered_data
# Out:
#                                                   Name      Price  \
# 0    ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...    ₹29,990
# 1    APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...    ₹94,990
# 2    DELL Inspiron Core i3 11th Gen 1115G4 - (8 GB/...    ₹36,590
# 3    HP 2023 Ryzen 3 Dual Core 3250U - (8 GB/512 GB...    ₹34,990
# 5    Acer One Core i3 11th Gen 1115G4 - (8 GB/512 G...    ₹25,990
# ..                                                 ...        ...
# 504  Lenovo Legion Slim 5 Ryzen 7 Octa Core 7840HS ...  ₹1,37,590
# 505  ASUS Vivobook Pro 15 OLED Core i5 12th Gen 124...    ₹89,990
# 506  DELL Inspiron Core i3 11th Gen 115G4 - (8 GB/2...    ₹35,990
# 507  MSI Core i7 12th Gen 1255U - (8 GB/512 GB SSD/...    ₹60,990
# 509  ASUS Core i5 12th Gen - (16 GB/512 GB SSD/Wind...    ₹70,990
#
#                               Processor                      Ram  \
# 0    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 1                    Apple M2 Processor  8 GB Unified Memory RAM
# 2    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 3       AMD Ryzen 3 Dual Core Processor            8 GB DDR4 RAM
# 5    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# ..                                  ...                      ...
# 504     AMD Ryzen 7 Octa Core Processor           16 GB DDR5 RAM
# 505  Intel Core i5 Processor (12th Gen)         16 GB LPDDR5 RAM
# 506  Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 507  Intel Core i7 Processor (12th Gen)            8 GB DDR4 RAM
# 509  Intel Core i5 Processor (12th Gen)           16 GB DDR4 RAM
#
#                                      OS     storage  \
# 0    64 bit Windows 11 Operating System  256 GB SSD
# 1               Mac OS Operating System  256 GB SSD
# 2    64 bit Windows 11 Operating System  512 GB SSD
# 3           Windows 11 Operating System  512 GB SSD
# 5    64 bit Windows 11 Operating System  512 GB SSD
# ..                                  ...         ...
# 504         Windows 11 Operating System  512 GB SSD
# 505  64 bit Windows 11 Operating System  512 GB SSD
# 506  64 bit Windows 10 Operating System  256 GB SSD
# 507         Windows 11 Operating System  512 GB SSD
# 509         Windows 11 Operating System  512 GB SSD
#
#                           Display  \
# 0    39.62 cm (15.6 Inch) Display
# 1    34.54 cm (13.6 Inch) Display
# 2    39.62 cm (15.6 inch) Display
# 3    39.62 cm (15.6 Inch) Display
# 5      35.56 cm (14 Inch) Display
# ..                            ...
# 504    40.64 cm (16 Inch) Display
# 505  39.62 cm (15.6 Inch) Display
# 506  39.62 cm (15.6 inch) Display
# 507    35.56 cm (14 Inch) Display
# 509  39.62 cm (15.6 inch) Display
#
#                                               warrenty
# 0                                       Not Applicable
# 1    Built-in Apps: iMovie, Siri, GarageBand, Pages...
# 2                               1 Year Onsite Warranty
# 3                               1 Year Onsite Warranty
# 5                                      1 Year Warranty
# ..                                                 ...
# 504               Microsoft Office Home & Student 2021
# 505                             1 Year Onsite Warranty
# 506              Office Home and Student 2019 included
# 507                           1 Year Carry-in warranty
# 509                                    1 Year Warranty
#
# [491 rows x 8 columns]

# %%
#Filtering with respect to Storage columns
keywords = ['SSD', 'HDD']
pattern = '|'.join(keywords)
filtered_data = filtered_data[filtered_data['storage'].str.contains(pattern, case=False, regex=True)]
filtered_data
# Out:
#                                                   Name      Price  \
# 0    ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...    ₹29,990
# 1    APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...    ₹94,990
# 2    DELL Inspiron Core i3 11th Gen 1115G4 - (8 GB/...    ₹36,590
# 3    HP 2023 Ryzen 3 Dual Core 3250U - (8 GB/512 GB...    ₹34,990
# 5    Acer One Core i3 11th Gen 1115G4 - (8 GB/512 G...    ₹25,990
# ..                                                 ...        ...
# 504  Lenovo Legion Slim 5 Ryzen 7 Octa Core 7840HS ...  ₹1,37,590
# 505  ASUS Vivobook Pro 15 OLED Core i5 12th Gen 124...    ₹89,990
# 506  DELL Inspiron Core i3 11th Gen 115G4 - (8 GB/2...    ₹35,990
# 507  MSI Core i7 12th Gen 1255U - (8 GB/512 GB SSD/...    ₹60,990
# 509  ASUS Core i5 12th Gen - (16 GB/512 GB SSD/Wind...    ₹70,990
#
#                               Processor                      Ram  \
# 0    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 1                    Apple M2 Processor  8 GB Unified Memory RAM
# 2    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 3       AMD Ryzen 3 Dual Core Processor            8 GB DDR4 RAM
# 5    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# ..                                  ...                      ...
# 504     AMD Ryzen 7 Octa Core Processor           16 GB DDR5 RAM
# 505  Intel Core i5 Processor (12th Gen)         16 GB LPDDR5 RAM
# 506  Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 507  Intel Core i7 Processor (12th Gen)            8 GB DDR4 RAM
# 509  Intel Core i5 Processor (12th Gen)           16 GB DDR4 RAM
#
#                                      OS     storage  \
# 0    64 bit Windows 11 Operating System  256 GB SSD
# 1               Mac OS Operating System  256 GB SSD
# 2    64 bit Windows 11 Operating System  512 GB SSD
# 3           Windows 11 Operating System  512 GB SSD
# 5    64 bit Windows 11 Operating System  512 GB SSD
# ..                                  ...         ...
# 504         Windows 11 Operating System  512 GB SSD
# 505  64 bit Windows 11 Operating System  512 GB SSD
# 506  64 bit Windows 10 Operating System  256 GB SSD
# 507         Windows 11 Operating System  512 GB SSD
# 509         Windows 11 Operating System  512 GB SSD
#
#                           Display  \
# 0    39.62 cm (15.6 Inch) Display
# 1    34.54 cm (13.6 Inch) Display
# 2    39.62 cm (15.6 inch) Display
# 3    39.62 cm (15.6 Inch) Display
# 5      35.56 cm (14 Inch) Display
# ..                            ...
# 504    40.64 cm (16 Inch) Display
# 505  39.62 cm (15.6 Inch) Display
# 506  39.62 cm (15.6 inch) Display
# 507    35.56 cm (14 Inch) Display
# 509  39.62 cm (15.6 inch) Display
#
#                                               warrenty
# 0                                       Not Applicable
# 1    Built-in Apps: iMovie, Siri, GarageBand, Pages...
# 2                               1 Year Onsite Warranty
# 3                               1 Year Onsite Warranty
# 5                                      1 Year Warranty
# ..                                                 ...
# 504               Microsoft Office Home & Student 2021
# 505                             1 Year Onsite Warranty
# 506              Office Home and Student 2019 included
# 507                           1 Year Carry-in warranty
# 509                                    1 Year Warranty
#
# [490 rows x 8 columns]

# %%
filtered_data['storage'].unique()
# Out:
# array(['256 GB SSD', '512 GB SSD', '1 TB SSD', '1 TB HDD', '2 TB SSD',
#        '1 TB HDD|256 GB SSD', '128 GB SSD', '1 TB HDD|1 TB SSD',
#        '1 TB HDD|128 GB SSD'], dtype=object)

# %%
#Filtering with respect to Operating system column
keywords = ['Operating System']
pattern = '|'.join(keywords)
filtered_data = filtered_data[filtered_data['OS'].str.contains(pattern, case=False, regex=True)]
filtered_data
# Out:
#                                                   Name      Price  \
# 0    ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...    ₹29,990
# 1    APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...    ₹94,990
# 2    DELL Inspiron Core i3 11th Gen 1115G4 - (8 GB/...    ₹36,590
# 3    HP 2023 Ryzen 3 Dual Core 3250U - (8 GB/512 GB...    ₹34,990
# 5    Acer One Core i3 11th Gen 1115G4 - (8 GB/512 G...    ₹25,990
# ..                                                 ...        ...
# 504  Lenovo Legion Slim 5 Ryzen 7 Octa Core 7840HS ...  ₹1,37,590
# 505  ASUS Vivobook Pro 15 OLED Core i5 12th Gen 124...    ₹89,990
# 506  DELL Inspiron Core i3 11th Gen 115G4 - (8 GB/2...    ₹35,990
# 507  MSI Core i7 12th Gen 1255U - (8 GB/512 GB SSD/...    ₹60,990
# 509  ASUS Core i5 12th Gen - (16 GB/512 GB SSD/Wind...    ₹70,990
#
#                               Processor                      Ram  \
# 0    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 1                    Apple M2 Processor  8 GB Unified Memory RAM
# 2    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 3       AMD Ryzen 3 Dual Core Processor            8 GB DDR4 RAM
# 5    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# ..                                  ...                      ...
# 504     AMD Ryzen 7 Octa Core Processor           16 GB DDR5 RAM
# 505  Intel Core i5 Processor (12th Gen)         16 GB LPDDR5 RAM
# 506  Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 507  Intel Core i7 Processor (12th Gen)            8 GB DDR4 RAM
# 509  Intel Core i5 Processor (12th Gen)           16 GB DDR4 RAM
#
#                                      OS     storage  \
# 0    64 bit Windows 11 Operating System  256 GB SSD
# 1               Mac OS Operating System  256 GB SSD
# 2    64 bit Windows 11 Operating System  512 GB SSD
# 3           Windows 11 Operating System  512 GB SSD
# 5    64 bit Windows 11 Operating System  512 GB SSD
# ..                                  ...         ...
# 504         Windows 11 Operating System  512 GB SSD
# 505  64 bit Windows 11 Operating System  512 GB SSD
# 506  64 bit Windows 10 Operating System  256 GB SSD
# 507         Windows 11 Operating System  512 GB SSD
# 509         Windows 11 Operating System  512 GB SSD
#
#                           Display  \
# 0    39.62 cm (15.6 Inch) Display
# 1    34.54 cm (13.6 Inch) Display
# 2    39.62 cm (15.6 inch) Display
# 3    39.62 cm (15.6 Inch) Display
# 5      35.56 cm (14 Inch) Display
# ..                            ...
# 504    40.64 cm (16 Inch) Display
# 505  39.62 cm (15.6 Inch) Display
# 506  39.62 cm (15.6 inch) Display
# 507    35.56 cm (14 Inch) Display
# 509  39.62 cm (15.6 inch) Display
#
#                                               warrenty
# 0                                       Not Applicable
# 1    Built-in Apps: iMovie, Siri, GarageBand, Pages...
# 2                               1 Year Onsite Warranty
# 3                               1 Year Onsite Warranty
# 5                                      1 Year Warranty
# ..                                                 ...
# 504               Microsoft Office Home & Student 2021
# 505                             1 Year Onsite Warranty
# 506              Office Home and Student 2019 included
# 507                           1 Year Carry-in warranty
# 509                                    1 Year Warranty
#
# [490 rows x 8 columns]

# %%
filtered_data['OS'].unique()
# Out:
# array(['64 bit Windows 11 Operating System', 'Mac OS Operating System',
#        'Windows 11 Operating System', 'DOS Operating System',
#        '64 bit Windows 10 Operating System',
#        '64 bit DOS Operating System', 'Windows 11 Home Operating System',
#        'Linux/Ubuntu Operating System', 'Windows 10 Operating System',
#        '64 bit Linux/Ubuntu Operating System'], dtype=object)

# %%
#Filtering with respect to RAM column
keywords = ['RAM']
pattern = '|'.join(keywords)
filtered_data = filtered_data[filtered_data['Ram'].str.contains(pattern, case=False, regex=True)]
filtered_data
# Out:
#                                                   Name      Price  \
# 0    ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...    ₹29,990
# 1    APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...    ₹94,990
# 2    DELL Inspiron Core i3 11th Gen 1115G4 - (8 GB/...    ₹36,590
# 3    HP 2023 Ryzen 3 Dual Core 3250U - (8 GB/512 GB...    ₹34,990
# 5    Acer One Core i3 11th Gen 1115G4 - (8 GB/512 G...    ₹25,990
# ..                                                 ...        ...
# 504  Lenovo Legion Slim 5 Ryzen 7 Octa Core 7840HS ...  ₹1,37,590
# 505  ASUS Vivobook Pro 15 OLED Core i5 12th Gen 124...    ₹89,990
# 506  DELL Inspiron Core i3 11th Gen 115G4 - (8 GB/2...    ₹35,990
# 507  MSI Core i7 12th Gen 1255U - (8 GB/512 GB SSD/...    ₹60,990
# 509  ASUS Core i5 12th Gen - (16 GB/512 GB SSD/Wind...    ₹70,990
#
#                               Processor                      Ram  \
# 0    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 1                    Apple M2 Processor  8 GB Unified Memory RAM
# 2    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 3       AMD Ryzen 3 Dual Core Processor            8 GB DDR4 RAM
# 5    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# ..                                  ...                      ...
# 504     AMD Ryzen 7 Octa Core Processor           16 GB DDR5 RAM
# 505  Intel Core i5 Processor (12th Gen)         16 GB LPDDR5 RAM
# 506  Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 507  Intel Core i7 Processor (12th Gen)            8 GB DDR4 RAM
# 509  Intel Core i5 Processor (12th Gen)           16 GB DDR4 RAM
#
#                                      OS     storage  \
# 0    64 bit Windows 11 Operating System  256 GB SSD
# 1               Mac OS Operating System  256 GB SSD
# 2    64 bit Windows 11 Operating System  512 GB SSD
# 3           Windows 11 Operating System  512 GB SSD
# 5    64 bit Windows 11 Operating System  512 GB SSD
# ..                                  ...         ...
# 504         Windows 11 Operating System  512 GB SSD
# 505  64 bit Windows 11 Operating System  512 GB SSD
# 506  64 bit Windows 10 Operating System  256 GB SSD
# 507         Windows 11 Operating System  512 GB SSD
# 509         Windows 11 Operating System  512 GB SSD
#
#                           Display  \
# 0    39.62 cm (15.6 Inch) Display
# 1    34.54 cm (13.6 Inch) Display
# 2    39.62 cm (15.6 inch) Display
# 3    39.62 cm (15.6 Inch) Display
# 5      35.56 cm (14 Inch) Display
# ..                            ...
# 504    40.64 cm (16 Inch) Display
# 505  39.62 cm (15.6 Inch) Display
# 506  39.62 cm (15.6 inch) Display
# 507    35.56 cm (14 Inch) Display
# 509  39.62 cm (15.6 inch) Display
#
#                                               warrenty
# 0                                       Not Applicable
# 1    Built-in Apps: iMovie, Siri, GarageBand, Pages...
# 2                               1 Year Onsite Warranty
# 3                               1 Year Onsite Warranty
# 5                                      1 Year Warranty
# ..                                                 ...
# 504               Microsoft Office Home & Student 2021
# 505                             1 Year Onsite Warranty
# 506              Office Home and Student 2019 included
# 507                           1 Year Carry-in warranty
# 509                                    1 Year Warranty
#
# [490 rows x 8 columns]

# %%
filtered_data['Ram'].unique()
# Out:
# array(['8 GB DDR4 RAM', '8 GB Unified Memory RAM', '16 GB DDR4 RAM',
#        '4 GB DDR4 RAM', '8 GB LPDDR4X RAM', '8 GB LPDDR5 RAM',
#        '16 GB LPDDR4X RAM', '32 GB DDR5 RAM', '16 GB DDR RAM',
#        '16 GB LPDDR5 RAM', '8 GB DDR5 RAM', '16 GB DDR5 RAM',
#        '8 GB DDR RAM', '16 GB LPDDR5X RAM', '8 GB DDR3 RAM',
#        '32 GB Unified Memory RAM', '64 GB DDR5 RAM', '32 GB LPDDR5 RAM',
#        '16 GB DDR4X RAM', '16 GB Unified Memory RAM', '16 GB LPDDR3 RAM',
#        '32 GB LPDDR4X RAM'], dtype=object)

# %%
#Filtering with respect to RAM column
keywords = ['RAM']
pattern = '|'.join(keywords)
filtered_data = filtered_data[filtered_data['Ram'].str.contains(pattern, case=False, regex=True)]
filtered_data
# Out:
#                                                   Name      Price  \
# 0    ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...    ₹29,990
# 1    APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...    ₹94,990
# 2    DELL Inspiron Core i3 11th Gen 1115G4 - (8 GB/...    ₹36,590
# 3    HP 2023 Ryzen 3 Dual Core 3250U - (8 GB/512 GB...    ₹34,990
# 5    Acer One Core i3 11th Gen 1115G4 - (8 GB/512 G...    ₹25,990
# ..                                                 ...        ...
# 504  Lenovo Legion Slim 5 Ryzen 7 Octa Core 7840HS ...  ₹1,37,590
# 505  ASUS Vivobook Pro 15 OLED Core i5 12th Gen 124...    ₹89,990
# 506  DELL Inspiron Core i3 11th Gen 115G4 - (8 GB/2...    ₹35,990
# 507  MSI Core i7 12th Gen 1255U - (8 GB/512 GB SSD/...    ₹60,990
# 509  ASUS Core i5 12th Gen - (16 GB/512 GB SSD/Wind...    ₹70,990
#
#                               Processor                      Ram  \
# 0    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 1                    Apple M2 Processor  8 GB Unified Memory RAM
# 2    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 3       AMD Ryzen 3 Dual Core Processor            8 GB DDR4 RAM
# 5    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# ..                                  ...                      ...
# 504     AMD Ryzen 7 Octa Core Processor           16 GB DDR5 RAM
# 505  Intel Core i5 Processor (12th Gen)         16 GB LPDDR5 RAM
# 506  Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 507  Intel Core i7 Processor (12th Gen)            8 GB DDR4 RAM
# 509  Intel Core i5 Processor (12th Gen)           16 GB DDR4 RAM
#
#                                      OS     storage  \
# 0    64 bit Windows 11 Operating System  256 GB SSD
# 1               Mac OS Operating System  256 GB SSD
# 2    64 bit Windows 11 Operating System  512 GB SSD
# 3           Windows 11 Operating System  512 GB SSD
# 5    64 bit Windows 11 Operating System  512 GB SSD
# ..                                  ...         ...
# 504         Windows 11 Operating System  512 GB SSD
# 505  64 bit Windows 11 Operating System  512 GB SSD
# 506  64 bit Windows 10 Operating System  256 GB SSD
# 507         Windows 11 Operating System  512 GB SSD
# 509         Windows 11 Operating System  512 GB SSD
#
#                           Display  \
# 0    39.62 cm (15.6 Inch) Display
# 1    34.54 cm (13.6 Inch) Display
# 2    39.62 cm (15.6 inch) Display
# 3    39.62 cm (15.6 Inch) Display
# 5      35.56 cm (14 Inch) Display
# ..                            ...
# 504    40.64 cm (16 Inch) Display
# 505  39.62 cm (15.6 Inch) Display
# 506  39.62 cm (15.6 inch) Display
# 507    35.56 cm (14 Inch) Display
# 509  39.62 cm (15.6 inch) Display
#
#                                               warrenty
# 0                                       Not Applicable
# 1    Built-in Apps: iMovie, Siri, GarageBand, Pages...
# 2                               1 Year Onsite Warranty
# 3                               1 Year Onsite Warranty
# 5                                      1 Year Warranty
# ..                                                 ...
# 504               Microsoft Office Home & Student 2021
# 505                             1 Year Onsite Warranty
# 506              Office Home and Student 2019 included
# 507                           1 Year Carry-in warranty
# 509                                    1 Year Warranty
#
# [490 rows x 8 columns]

# %%
filtered_data['Processor'].unique()
# Out:
# array(['Intel Core i3 Processor (11th Gen)', 'Apple M2 Processor',
#        'AMD Ryzen 3 Dual Core Processor',
#        'AMD Ryzen 5 Hexa Core Processor',
#        'Intel Core i5 Processor (12th Gen)',
#        'AMD Athlon Dual Core Processor',
#        'Intel Celeron Dual Core Processor',
#        'Intel Core i3 Processor (10th Gen)',
#        'AMD Ryzen 5 Quad Core Processor',
#        'Intel Core i7 Processor (12th Gen)',
#        'Intel Core i3 Processor (12th Gen)',
#        'AMD Ryzen 3 Quad Core Processor',
#        'AMD Ryzen 3 Hexa Core Processor', 'Apple M1 Processor',
#        'Intel Core i3 Processor', 'Intel Core i7 Processor (11th Gen)',
#        'Intel Core i5 Processor (11th Gen)',
#        'AMD Ryzen 9 16 Core Processor',
#        'Intel Celeron Quad Core Processor (11th Gen)',
#        'AMD Ryzen 7 Octa Core Processor',
#        'AMD Ryzen 5 Octa Core Processor',
#        'AMD Core i3 Processor (11th Gen)',
#        'Intel Core i3 Processor (13th Gen)',
#        'AMD Ryzen 5 Dual Core Processor',
#        'Intel Core i7 Processor (13th Gen)',
#        'Intel Core i9 Processor (13th Gen)',
#        'Intel Core i5 Processor (13th Gen)',
#        'AMD Ryzen 7 Octa Core Processor (5th Gen)',
#        'Intel Celeron Quad Core Processor',
#        'Intel Core i7 Processor (8th Gen)',
#        'Intel Celeron Dual Core Processor (4th Gen)',
#        'AMD Ryzen 9 Octa Core Processor',
#        'Intel Core i5 Processor (10th Gen)',
#        'Intel Core i7 Processor (10th Gen)',
#        'Intel Core i5 Processor (7th Gen)',
#        'Intel Ryzen 3 Quad Core Processor', 'Apple M2 Max Processor',
#        'Intel Core i9 Processor (12th Gen)', 'Apple M1 Max Processor',
#        'AMD Ryzen 5 Hexa Core Processor (13th Gen)',
#        'AMD APU Dual Core A6 Processor', 'Apple M2 Pro Processor',
#        'AMD Ryzen 9 Octa Core Processor (10th Gen)',
#        'AMD Ryzen 7 Octa Core Processor (7th Gen)',
#        'AMD Ryzen 5 Processor (10th Gen)',
#        'Intel Pentium Silver Processor', 'Intel Hexa Core i5 Processor',
#        'Intel Core i7 Processor (7th Gen)',
#        'AMD Ryzen 7 Octa Core Processor (10th Gen)',
#        'Intel Core i5 Processor', 'Intel Core i5 Processor (8th Gen)'],
#       dtype=object)

# %%
# Cleaned Data
data= filtered_data.reset_index(drop=True)
data
# Out:
#                                                   Name      Price  \
# 0    ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...    ₹29,990
# 1    APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...    ₹94,990
# 2    DELL Inspiron Core i3 11th Gen 1115G4 - (8 GB/...    ₹36,590
# 3    HP 2023 Ryzen 3 Dual Core 3250U - (8 GB/512 GB...    ₹34,990
# 4    Acer One Core i3 11th Gen 1115G4 - (8 GB/512 G...    ₹25,990
# ..                                                 ...        ...
# 485  Lenovo Legion Slim 5 Ryzen 7 Octa Core 7840HS ...  ₹1,37,590
# 486  ASUS Vivobook Pro 15 OLED Core i5 12th Gen 124...    ₹89,990
# 487  DELL Inspiron Core i3 11th Gen 115G4 - (8 GB/2...    ₹35,990
# 488  MSI Core i7 12th Gen 1255U - (8 GB/512 GB SSD/...    ₹60,990
# 489  ASUS Core i5 12th Gen - (16 GB/512 GB SSD/Wind...    ₹70,990
#
#                               Processor                      Ram  \
# 0    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 1                    Apple M2 Processor  8 GB Unified Memory RAM
# 2    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 3       AMD Ryzen 3 Dual Core Processor            8 GB DDR4 RAM
# 4    Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# ..                                  ...                      ...
# 485     AMD Ryzen 7 Octa Core Processor           16 GB DDR5 RAM
# 486  Intel Core i5 Processor (12th Gen)         16 GB LPDDR5 RAM
# 487  Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 488  Intel Core i7 Processor (12th Gen)            8 GB DDR4 RAM
# 489  Intel Core i5 Processor (12th Gen)           16 GB DDR4 RAM
#
#                                      OS     storage  \
# 0    64 bit Windows 11 Operating System  256 GB SSD
# 1               Mac OS Operating System  256 GB SSD
# 2    64 bit Windows 11 Operating System  512 GB SSD
# 3           Windows 11 Operating System  512 GB SSD
# 4    64 bit Windows 11 Operating System  512 GB SSD
# ..                                  ...         ...
# 485         Windows 11 Operating System  512 GB SSD
# 486  64 bit Windows 11 Operating System  512 GB SSD
# 487  64 bit Windows 10 Operating System  256 GB SSD
# 488         Windows 11 Operating System  512 GB SSD
# 489         Windows 11 Operating System  512 GB SSD
#
#                           Display  \
# 0    39.62 cm (15.6 Inch) Display
# 1    34.54 cm (13.6 Inch) Display
# 2    39.62 cm (15.6 inch) Display
# 3    39.62 cm (15.6 Inch) Display
# 4      35.56 cm (14 Inch) Display
# ..                            ...
# 485    40.64 cm (16 Inch) Display
# 486  39.62 cm (15.6 Inch) Display
# 487  39.62 cm (15.6 inch) Display
# 488    35.56 cm (14 Inch) Display
# 489  39.62 cm (15.6 inch) Display
#
#                                               warrenty
# 0                                       Not Applicable
# 1    Built-in Apps: iMovie, Siri, GarageBand, Pages...
# 2                               1 Year Onsite Warranty
# 3                               1 Year Onsite Warranty
# 4                                      1 Year Warranty
# ..                                                 ...
# 485               Microsoft Office Home & Student 2021
# 486                             1 Year Onsite Warranty
# 487              Office Home and Student 2019 included
# 488                           1 Year Carry-in warranty
# 489                                    1 Year Warranty
#
# [490 rows x 8 columns]

# %%
#making the price column to Integer
data['Price'] = data['Price'].str.replace('₹', '')

# %%
#removing , from price column
data['Price'] = data['Price'].str.replace(',', '').astype(int)
data.head()
# Out:
#                                                 Name  Price  \
# 0  ASUS Vivobook 15 Core i3 11th Gen 1115G4 - (8 ...  29990
# 1  APPLE 2022 MacBook AIR M2 - (8 GB/256 GB SSD/M...  94990
# 2  DELL Inspiron Core i3 11th Gen 1115G4 - (8 GB/...  36590
# 3  HP 2023 Ryzen 3 Dual Core 3250U - (8 GB/512 GB...  34990
# 4  Acer One Core i3 11th Gen 1115G4 - (8 GB/512 G...  25990
#
#                             Processor                      Ram  \
# 0  Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 1                  Apple M2 Processor  8 GB Unified Memory RAM
# 2  Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
# 3     AMD Ryzen 3 Dual Core Processor            8 GB DDR4 RAM
# 4  Intel Core i3 Processor (11th Gen)            8 GB DDR4 RAM
#
#                                    OS     storage  \
# 0  64 bit Windows 11 Operating System  256 GB SSD
# 1             Mac OS Operating System  256 GB SSD
# 2  64 bit Windows 11 Operating System  512 GB SSD
# 3         Windows 11 Operating System  512 GB SSD
# 4  64 bit Windows 11 Operating System  512 GB SSD
#
#                         Display  \
# 0  39.62 cm (15.6 Inch) Display
# 1  34.54 cm (13.6 Inch) Display
# 2  39.62 cm (15.6 inch) Display
# 3  39.62 cm (15.6 Inch) Display
# 4    35.56 cm (14 Inch) Display
#
#                                             warrenty
# 0                                     Not Applicable
# 1  Built-in Apps: iMovie, Siri, GarageBand, Pages...
# 2                             1 Year Onsite Warranty
# 3                             1 Year Onsite Warranty
# 4                                    1 Year Warranty

# %%
data.dtypes
# Out:
# Name         object
# Price         int64
# Processor    object
# Ram          object
# OS           object
# storage      object
# Display      object
# warrenty     object
# dtype: object

# %%
data.describe(include='all')
# Out:
#                                                      Name          Price  \
# count                                                 490     490.000000
# unique                                                472            NaN
# top     MSI Core i7 11th Gen 11800H - (8 GB/512 GB SSD...            NaN
# freq                                                    2            NaN
# mean                                                  NaN   75077.522449
# std                                                   NaN   57072.772133
# min                                                   NaN   16069.000000
# 25%                                                   NaN   40990.000000
# 50%                                                   NaN   58990.000000
# 75%                                                   NaN   85990.000000
# max                                                   NaN  477890.000000
#
#                                  Processor            Ram  \
# count                                  490            490
# unique                                  51             22
# top     Intel Core i5 Processor (12th Gen)  8 GB DDR4 RAM
# freq                                    69            205
# mean                                   NaN            NaN
# std                                    NaN            NaN
# min                                    NaN            NaN
# 25%                                    NaN            NaN
# 50%                                    NaN            NaN
# 75%                                    NaN            NaN
# max                                    NaN            NaN
#
#                                  OS     storage                       Display  \
# count                           490         490                           490
# unique                           10           9                            42
# top     Windows 11 Operating System  512 GB SSD  39.62 cm (15.6 Inch) Display
# freq                            248         343                           165
# mean                            NaN         NaN                           NaN
# std                             NaN         NaN                           NaN
# min                             NaN         NaN                           NaN
# 25%                             NaN         NaN                           NaN
# 50%                             NaN         NaN                           NaN
# 75%                             NaN         NaN                           NaN
# max                             NaN         NaN                           NaN
#
#                       warrenty
# count                      490
# unique                     110
# top     1 Year Onsite Warranty
# freq                       198
# mean                       NaN
# std                        NaN
# min                        NaN
# 25%                        NaN
# 50%                        NaN
# 75%                        NaN
# max                        NaN

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 490 entries, 0 to 489
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       490 non-null    object
#  1   Price      490 non-null    int64
#  2   Processor  490 non-null    object
#  3   Ram        490 non-null    object
#  4   OS         490 non-null    object
#  5   storage    490 non-null    object
#  6   Display    490 non-null    object
#  7   warrenty   490 non-null    object
# dtypes: int64(1), object(7)
# memory usage: 30.8+ KB

# %%
plt.figure(figsize=(10,8))
sns.distplot(data['Price'])
# Out:
# <ipython-input-100-d925f5cd67d8>:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['Price'])
# <Axes: xlabel='Price', ylabel='Density'>

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 8))
sns.boxplot(data['Price'])
plt.xticks(rotation=90)
plt.title("Boxplot of Laptop Prices")
# Out:
# Text(0.5, 1.0, 'Boxplot of Laptop Prices')

# %%
df1 = data
df1['Name'] = df1['Name'].str.split().str[:4].str.join(' ')
df1.head()
# Out:
#                        Name  Price                           Processor  \
# 0     DELL Inspiron Core i3  36590  Intel Core i3 Processor (11th Gen)
# 1           HP 2023 Ryzen 3  34990     AMD Ryzen 3 Dual Core Processor
# 2          Acer One Core i3  25990  Intel Core i3 Processor (11th Gen)
# 3        Lenovo V15 Ryzen 5  34604     AMD Ryzen 5 Hexa Core Processor
# 4  ASUS Vivobook 16X (2023)  79990  Intel Core i5 Processor (12th Gen)
#
#               Ram                                  OS     storage  \
# 0   8 GB DDR4 RAM  64 bit Windows 11 Operating System  512 GB SSD
# 1   8 GB DDR4 RAM         Windows 11 Operating System  512 GB SSD
# 2   8 GB DDR4 RAM  64 bit Windows 11 Operating System  512 GB SSD
# 3   8 GB DDR4 RAM         Windows 11 Operating System  512 GB SSD
# 4  16 GB DDR4 RAM         Windows 11 Operating System  512 GB SSD
#
#                         Display                warrenty
# 0  39.62 cm (15.6 inch) Display  1 Year Onsite Warranty
# 1  39.62 cm (15.6 Inch) Display  1 Year Onsite Warranty
# 2    35.56 cm (14 Inch) Display         1 Year Warranty
# 3  39.62 cm (15.6 Inch) Display  1 Year Onsite Warranty
# 4    40.64 cm (16 Inch) Display  1 Year Onsite Warranty

# %%
sns.set(style="whitegrid")
plt.figure(figsize=(10, 8))
scatterplot = sns.scatterplot(x='Name', y="Price", data=df1)
plt.xticks(rotation=90)
plt.xlabel("Laptop Name")
plt.ylabel("Price")
plt.title("Scatterplot of Laptop Prices")
# Out:
# Text(0.5, 1.0, 'Scatterplot of Laptop Prices')

# %%
plt.figure(figsize=(10, 8))
scatterplot = sns.scatterplot(x='Ram', y="Price", data=data)
plt.xticks(rotation=90)
plt.xlabel("RAM")
plt.ylabel("Price")
plt.title("Scatterplot of Laptop Prices")
# Out:
# Text(0.5, 1.0, 'Scatterplot of Laptop Prices')

# %%
pal = sns.color_palette()
plt.figure(figsize=(10, 8))
countplot = sns.countplot(x='Ram', data=data, palette=pal)
plt.xticks(rotation=90)
plt.xlabel("RAM")
plt.title("countplot on RAM")
# Out:
# Text(0.5, 1.0, 'countplot on RAM')

# %%
plt.figure(figsize=(10, 8))
scatterplot = sns.scatterplot(x='Processor', y="Price", data=data)
plt.xticks(rotation=90)
plt.xlabel("Processor")
plt.ylabel("Price")
plt.title("Scatterplot of Laptop Prices")
# Out:
# Text(0.5, 1.0, 'Scatterplot of Laptop Prices')

# %%
pal = sns.color_palette()
plt.figure(figsize=(10, 8))
countplot = sns.countplot(x='Processor', data=data, palette=pal)
plt.xticks(rotation=90)
plt.xlabel("RAM")
plt.title("countplot on Processor")
# Out:
# Text(0.5, 1.0, 'countplot on Processor')

# %%
plt.figure(figsize=(10, 8))
scatterplot = sns.scatterplot(x='Display', y="Price", data=data)
plt.xticks(rotation=90)
plt.xlabel("Display")
plt.ylabel("Price")
plt.title("Scatterplot of Laptop Prices")
# Out:
# Text(0.5, 1.0, 'Scatterplot of Laptop Prices')

# %%
pal = sns.color_palette()
plt.figure(figsize=(10, 8))
countplot = sns.countplot(x='Display', data=data, palette=pal)
plt.xticks(rotation=90)
plt.xlabel("Display")
plt.title("countplot on Display")
# Out:
# Text(0.5, 1.0, 'countplot on Display')
